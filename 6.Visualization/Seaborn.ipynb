# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
x=["Mon","Tue","Wed","Thu","Fri","Sat","Sun"]
y=[10,23,8,18,3,25,30]

# %%
new=sns.stripplot(x,y)
new.set(xlabel="Days",ylabel="Count")
plt.title("Strip Plot")
plt.show()
# Out:
# C:\Users\SHUBHAM\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.distplot([0,1,2,3,4,5])
plt.show()
# Out:
# C:\Users\SHUBHAM\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot([0,1,2,3,4,5],hist=False)
plt.show()
# Out:
# C:\Users\SHUBHAM\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
df=pd.read_csv("Iris.csv")
df
# Out:
#      Sepal_Length  Sepal_Width  Petal_Length  Petal_Width    Species
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
sns.stripplot(df["Species"],df["Sepal_Length"])
plt.title("Strip Plot")
plt.xlabel("Species")
plt.ylabel("Sepal_Length")
plt.show()
# Out:
# C:\Users\SHUBHAM\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.swarmplot(df["Species"],df["Sepal_Length"])
plt.title("Strip Plot")
plt.xlabel("Species")
plt.ylabel("Sepal_Length")
plt.show()
# Out:
# C:\Users\SHUBHAM\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.swarmplot(df["Sepal_Length"],df["Species"])#Bcoz the categrical are in y
plt.title("Strip Plot")
plt.xlabel("Species")
plt.ylabel("Sepal_Length")
plt.show()
# Out:
# C:\Users\SHUBHAM\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.barplot(df["Species"],df["Sepal_Length"])
plt.title("Bar Plot")
plt.xlabel("Species")
plt.ylabel("Sepal_Length")
plt.show()
# Out:
# C:\Users\SHUBHAM\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.barplot(df["Species"],df["Sepal_Length"],palette="cool")#palette for colour (plasma,Greens_d,etc)
plt.title("Bar Plot")
plt.xlabel("Species")
plt.ylabel("Sepal_Length")
plt.show()
# Out:
# C:\Users\SHUBHAM\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
new=sns.countplot(df["Species"])#Categrical column can pass to count
new.set(xlabel="Species",ylabel="Count")
plt.title("Count Plot of Species")
plt.show()
# Out:
# C:\Users\SHUBHAM\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
new1=sns.boxplot(df["Species"],df["Sepal_Length"])
new1.set(xlabel="Species",ylabel="Count")
plt.title("Box Plot of Species vs Sepal_length")
plt.show()
# Out:
# C:\Users\SHUBHAM\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
new1=sns.violinplot(df["Species"],df["Sepal_Length"])
new1.set(xlabel="Species",ylabel="Count")
plt.title("Violin Plot of Species vs Sepal_length")
plt.show()
# Out:
# C:\Users\SHUBHAM\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
pd.get_dummies(df)
# Out:
#      Sepal_Length  Sepal_Width  Petal_Length  Petal_Width  Species_Setosa  \
# 0             5.1          3.5           1.4          0.2               1
# 1             4.9          3.0           1.4          0.2               1
# 2             4.7          3.2           1.3          0.2               1
# 3             4.6          3.1           1.5          0.2               1
# 4             5.0          3.6           1.4          0.2               1
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3               0
# 146           6.3          2.5           5.0          1.9               0
# 147           6.5          3.0           5.2          2.0               0
# 148           6.2          3.4           5.4          2.3               0
# 149           5.9          3.0           5.1          1.8               0
#
#      Species_Versicolor  Species_Virginica
# ...

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
df1=df.drop(["Species"],axis=1)
df1
# Out:
#      Sepal_Length  Sepal_Width  Petal_Length  Petal_Width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
# fig=plt.figure(figsize=(10,8))
sns.heatmap(df1.corr(),annot=True)#annot=True for values of correlation in the graph
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(df)

# %%
sns.pairplot(df,hue='Species',diag_kind='hist')

# %%
sns.jointplot(df["Petal_Width"],df["Sepal_Length"])#x=right,y=upper
# Out:
# C:\Users\SHUBHAM\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.scatterplot(df["Sepal_Length"], df["Sepal_Width"])
sns.despine()
# Out:
# C:\Users\SHUBHAM\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df.hist()
# Out:
# array([[<AxesSubplot:title={'center':'Sepal_Length'}>,
#         <AxesSubplot:title={'center':'Sepal_Width'}>],
#        [<AxesSubplot:title={'center':'Petal_Length'}>,
#         <AxesSubplot:title={'center':'Petal_Width'}>]], dtype=object)
